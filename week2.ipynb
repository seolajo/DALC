# %% [markdown]
# <a href="https://colab.research.google.com/github/seolajo/DALC/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5장 리스트, 딕셔너리

# %% [markdown]
# ---

# %% [markdown]
# ## 리스트

# %% [markdown]
# *   순서대로 저장하는 시퀀스이자 변경가능한 목록(Mutable List)
# *   입력 순서가 유지되며, 내부적으로는 동적 배열로 구현되어 있다.

# %% [markdown]
# p.121 표 5-1 각 언어별 동적 배열 구현
#
# >
# ![5-1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   스택과 큐에서 사용 가능한 모든 연산을 함께 제공
# *   또한 *O*(1)에 실행 가능한 연산들도 몇 가지 있다

# %% [markdown]
# p.122 표 5-2 리스트의 주요 연산 시간 복잡도
#
# > ![5-2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *  순차정렬 시에는 이진 검색이 효율적이다.
# *  순차정렬이 아닐 시, 최악의 경우 *O*(n)이 소요

# %% [markdown]
# ### 리스트의 활용 방법

# %% [markdown]
# 리스트는 다음과 같이 선언한다

# %%
a = list()

# %% [markdown]
# 대괄호로 더 간단히 선언할 수 있다

# %%
a = []

# %% [markdown]
# 초깃값 지정해 선언하거나, append()로 추가할 수 있다

# %%
a = [1,2,3]
print(a)
a.append(4)
print(a)

# %% [markdown]
# insert()함수를 사용하면 특정 위치의 인덱스를 지정해 요소를 추가할 수 있다. 다음과 같이 3번째 인덱스에(인덱스는 0부터 시작) 5를 삽입한다

# %%
a.insert(3,5)
print(a)

# %% [markdown]
# 숫자 외에도 문자와 불리언을 자유롭게 삽입할 수 있다

# %%
a.append('안녕')
a.append(True)
print(a)

# %% [markdown]
# 값을 꺼낼 땐 다음과 같이 간단히 인덱스를 지정하면 된다

# %%
a[3]

# %% [markdown]
# 파이썬 리스트에는 슬라이싱(slicing)기능이 있어 특정 범위 내의 값을 매우 편리하게 가져올 수 있다.

# %%
a[1:3]

# %% [markdown]
# 시작 인덱스는 다음과 같이 생략할 수 있다

# %%
a[:3]

# %% [markdown]
# 또는 종료 인덱스를 생략할 수도 있다

# %%
a[4:]

# %% [markdown]
# 다음과 같이 홀수 번째 인덱스의 값만 가져올 수도 있다

# %%
#세 번째 파라미터를 부여하면 '단계'의 의미로, 아래와 같이 2라고 지정할 경우
#인덱스 1부터 시작해 1에서 2칸 건너뛴 3까지의 값을 가져오게 된다.
a[1:4:2]

# %% [markdown]
# IndexError는 인덱스가 리스트의 길이를 넘어설 때 발생하며 다음과 같이 try구문으로 에러에 대한 예외 처리를 할 수 있다

# %%
try:
    print(a[9])
except IndexError:
    print('존재하지 않는 인덱스')

# %% [markdown]
# 리스트에서 요소를 삭제하는 방법은 크게 두 가지가 있다.
#
# *   인덱스로 삭제
# *   값으로 삭제

# %% [markdown]
# 1.   del 키워드를 사용하면 인덱스의 위치에 있는 요소를 삭제할 수 있다

# %%
del a[1]
print(a)

# %% [markdown]
# 2.   다음과 같이 remove()함수를 사용하면 값에 해당하는 요소를 삭제할 수 있다.

# %%
a.remove(3)
print(a)

# %% [markdown]
# 다음과 같이 pop()함수를 사용하면 스택의 팝(pop)연산 처럼 추출로 처리된다. 즉 삭제될 값을 리턴하고 삭제가 진행된다.

# %%
print(a)
a.pop(3)
print(a)

# %% [markdown]
# ### 리스트의 특징

# %% [markdown]
# 파이썬 리스트는 모두 제각각인 자료형을 단일 리스트에 통합해서 저장할 수 있다. 그러나 각 자료형의 크기는 저마다 서로 다르기 때문에 이들을 연속된 메모리 공간에 할당하는 것은 불가능하다. 결국 각각의 객체에 대한 참조로 구현할 수밖에 없다.
#
# 이처럼 파이썬은 강력한 기능을 위해 리스트와 객체에 대한 참조를 택했으며, 이로 인해 부득이하게 속도를 희생한 측면이 있다.

# %% [markdown]
# ## 딕셔너리

# %% [markdown]
# *   파이썬의 딕셔너리는 키/값 구조로 이뤄진 딕셔너리를 말한다.
# *   파이썬 3.7+에서는 입력 순서가 유지, 내부적으로 해시 테이블(Hash Table)로 구현

# %% [markdown]
# p.129 표 5-3 각 언어별 해시 테이블 구현
#
# > ![5-3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 숫자로만 인덱스를 지정할 수 있었던 리스트와 달리, 딕셔너리는 다양한 타입을 키로 사용할 수 있다. '해시'할 수만 있다면 문자, 집합까지 불변 객체를 모두 키로 사용할 수 있다.
#
# > 이 과정을 해싱이라하며, 해시 테이블을 이용해 자료를 저장한다.
#
# > 입력, 조회 모두 *O*(1)에 가능
#
# > 최악의 경우 *O*(n)이 될 수 있으나 대부분 더 빨리 실행
#
# >분할 상환 분석(Amortized Analysis)에 따른 시간 복잡도는 *O*(1)

# %% [markdown]
# p.129 표 5-4 딕셔너리의 주요 연산 시간 복잡도
#
# > ![5-4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 버전별 성능개선 참고사항
# *   파이썬 3.7+: 딕셔너리 입력 순서 유지
# *   파이썬 3.6+: 딕셔너리 메모리 사용량 20% 감소
#
# 딕셔너리 추가 모듈
#
#
# *   collections.OrderedDict(): 3.6 이하에서 항상 입력 순서가 유지
# *   collections.defaultdict(): 조회 시 항상 디폴트 값을 생성해 키 오류 방지
# *   collections.Counter(): 요소의 값을 키로, 개수를 값 형태로 카운팅

# %% [markdown]
# ### 딕셔너리의 활용 방법

# %% [markdown]
# 딕셔너리 선언

# %%
a = dict()

# %% [markdown]
# 중괄호를 활용한 더 간단한 선언

# %%
a = {}

# %% [markdown]
# 다음과 같이 초기값을 지정해 선언하거나, 나중에 별도로 선언하여 값을 할당할 수도 있다.

# %%
a = {'key1':'value1', 'key2':'value2'}
print(a)
a['key3'] = 'value3'
print(a)

# %% [markdown]
# 딕셔너리에서 존재하지 않는 키 조회 시, KeyError가 발생
# > 다음과 같이 try 구문으로 예외 처리할 수 있다.

# %%
try:
    print(a['key4'])
except KeyError:
    print('존재하지 않는 키')

# %% [markdown]
# 예외 처리를 하는 방법 외에, 키가 존재하는지 미리 확인해 이후 작업을 진행할 수도 있다.

# %%
#1
print('key4' in a)
#2
if 'key4' in a:
    print('존재하는 키')
else:
    print('존재하지 않는 키')
#어떤 키/값 있는지 확인
for k, v in a.items():
    print(k, v)

#삭제는 리스트와 같이 del a['key1'] 와 같은 형식으로 삭제

# %% [markdown]
# ### 딕셔너리 모듈

# %% [markdown]
# > 특수한 형태의 컨테이너 자료형: defaultdict, Counter, OrderedDict

# %% [markdown]
# defaultdict객체
#
# > 존재하지 않는 키를 조회할 경우, 에러 메시지 대신 디폴트 값을 기준으로 해당 키에 대한 딕셔너리 아이템을 생성
# * collections.defaultdict 클래스를 가짐

# %%
import collections

a = collections.defaultdict(int)
a['A'] = 5
a['B'] = 4
print(a)
a['C'] += 1
print(a)

# %% [markdown]
# 결과: defaultdict(<class 'int'>, {'A': 5, 'B': 4, 'C': 1})
# >디폴트인 0을 기준으로 C를 자동 생성 후 여기에 1을 더해 최종적으로 1이 만들어 진다.

# %% [markdown]
# Counter 객체
#
# > 아이템에 대한 개수를 계산해 딕셔너리로 리턴, 다음과 같이 사용한다.

# %%
a = [1,2,3,4,5,5,5,6,6]
b = collections.Counter(a)
print(b)

# %% [markdown]
# * Counter 객체는 이처럼 키에는 아이템의 값이, 값에는 해당 아이템의 개수가 들어간 딕셔너리를 생성
# * 실제로 다음과 같이 딕셔너리를 한 번 더 래핑(Wrapping)한 collections.Counter 클래스를 가진다

# %%
print(type(b))

# %% [markdown]
# most_common() : 가장 빈도수가 높은 요소 추출

# %%
b.most_common(2)

# %% [markdown]
# OrderedDict 객체
#
# > 파이썬 3.6 이하 버전에서 딕셔너리의 입력 순서를 유지

# %%
print(collections.OrderedDict({'banana':3, 'apple':4, 'pear':1, 'orange':2}))

# %% [markdown]
# 이름으로 타입을 선언할 수도 있지만(ex.a=list()), 기호로 더욱 간편하게 타입을 선언할 수 있다
#
# > 딕셔너리와 집합은 같은 중괄호를 사용하지만 `키의 존재 유무`로 서로 다른 자료형으로 선언된다.
# >아래처럼 키 없이 값만 1로 선언한 경우 집합 자료형이 된다.

# %%
type([])   #<class 'list'>
type(())   #<class 'tuple'>
type({})   #<class 'dict'>
type({1})  #<class 'set'>

# %% [markdown]
# # 6장 문자열 조작

# %% [markdown]
# 문자열 조작(String Manipulation) : 문자열을 변경하거나 분리하는 등의 여러 과정
#
# *  정보 처리 분야 : `어떤 키워드로 웹 페이지를 탐색할 때`
# *  통신 시스템 분야 : `문자 메시지나 이메일 보내는 등의 데이터 전송`
# *  프로그래밍 시스템 분야 : `프로그램 그 자체`

# %% [markdown]
# ## 01 유효한 팰린드롬
#
# > 뒤집어도 같은 말이 되는 단어 또는 문장을 팰린드롬(Palindrome)이라 한다. 우리말로는 '회문'이라하며, 예를 들면 "소주 만 병만 주소"와 같은 형식이다.

# %% [markdown]
# *  예제1
# 입력: "A man, a plan, a canal: Panama"
# 출력: true
#
#
# * 예제2
# 입력: "race a car"
# 출력: false

# %% [markdown]
# ### **풀이1** 리스트로 변환

# %% [markdown]
# 직접 문자열을 입력받아 팰린드롬 여부를 판별해본다.
# *제약조건: 대소문자 여부를 구분하지 않으며 영문자, 숫자만을 대상으로 함*
# 따라서 이 부분에 대한 `전처리`부터 다음과 같이 구현한다.
# *  isalnum()는 영문자, 숫자 여부를 판별하는 함수로, 이를 이용해 해당하는 문자만 추가한다.(따라서 콜론(:)은 추가 안함)
# *  대소문자를 구분하지 않으므로 lower()로 모두 소문자로 변환

# %%
s = "A man, a plan, a canal: Panama"

strs = []
for char in s:
    if char.isalnum():
        strs.append(char.lower())

print(strs)

# %% [markdown]
# 이제 다음과 같이 팰린드롬 여부를 판별해보자

# %%
while len(strs) > 1:
    if strs.pop(0) != strs.pop():
        return False

# %% [markdown]
# *  파이썬의 리스트는 pop()함수에서 인덱스를 지정할 수 있고, pop()는 맨 뒷부분의 결과를 보여준다.
# *  이렇게 맨 뒷부분의 pop()결과와 맨 앞부분의 pop(0) 결과를 매칭해 나가면서 일치하지 않는 경우 False를 리턴한다.
# *  모두 통과했다면 True를 리턴한다.

# %%
#전체 코드

s = "A man, a plan, a canal: Panama"

def isPalindrome(self, s: str) -> bool:
    strs = []
    for char in s:
        if char.isalnum():
            strs.append(char.lower())
    #팰린드롬 여부 판별
    while len(strs) > 1:
        if strs.pop(0) != strs.pop():
            return False

    return True

# %% [markdown]
# ### **풀이2** 데크 자료형을 이용한 최적화

# %% [markdown]
# 데크(Deque)를 명시적으로 선언하면 좀 더 속도를 높일 수 있다.

# %%
def isPalindrome(self, s: str) -> bool:
    #자료형 데크로 선언
    strs: Deque = collections.deque()

    for char in s:
        if char.isalnum():
            strs.append(char.lower())

    while len(strs) > 1:
        if strs.popleft() != strs.pop():
            return False

    return True

# %% [markdown]
# 여기서 strs: Deque = collections.deque()와 같이 자료형을 데크로 선언하는 것만으로 풀이1 대비 5배 가까이 속도를 높였다.
#
#   이는 리스트의 pop(0)이 O(n)인 데 반해, 데크의 popleft()는 O(1)이기 때문이며, 각각 n번씩 반복하면, 리스트 구현은 O(n^2), 데크 구현은 O(n)으로 성능 차이가 크다

# %% [markdown]
# ### **풀이3** 슬라이싱 사용

# %%
def isPalindrome(self, s: str) -> bool:
    s = s.lower()
    #정규식으로 불필요한 문자 필터링
    s = re.sub('[^a-z0-9]', '', s)

    return s == s[::-1] #슬라이싱

# %% [markdown]
# *  여기선 문자열 전체를 한 번에 영숫자(Alphanumeric)만 걸러내도록 정규식으로 처리했다.
# *  또한 파이썬은 문자열을 배열이나 리스트처럼 자유롭게 슬라이싱할 수 있는 좋은 기능을 제공, `[::-1]`을 이용하면 뒤집을 수 있다.
# *코드가 훨씬 간단해지며, 내부적으로 C로 빠르게 구현되어 있어 속도 빨라진다 -> 풀이2에 비해 약 2배 더 빨라짐

# %% [markdown]
# ## 02 문자열 뒤집기
#
# > 문자열을 뒤집는 함수를 작성하라. 입력값은 문자 배열이며, 리턴 없이 리스트 내부를 직접 조작하라.

# %% [markdown]
# *  예제1
# 입력 : `["h","e","l","l","o"]`
# 출력 : `["o","l","l","e","h"]`
#
# *  예제2
# 입력 : `["H","a","n","n","a","h"]`
# 출력 : `["h","a","n","n","a","h"]`

# %% [markdown]
# ### **풀이1** 투 포인터를 이용한 스왑

# %% [markdown]
# * 투 포인터 : 2개의 포인터를 이용해 범위를 조정해가며 풀이하는 방식을 말한다. 여기서는 점점 더 범위를 좁혀 가며 스왑하는 형태로 풀이할 수 있다.
#
# 문제에서는  *리턴 없이 리스트 내부를 직접 조작하라*는 제약 사항이 있으므로, 다음과 같이 `s 내부를 스왑하는 형태`로 풀이하면 된다.

# %%
def reverseString(self, s: List[str]) -> None:
    left, right = 0, len(s) - 1
    while left < right:
        s[left], s[right] = s[right], s[left]
        left += 1
        right -= 1

# %% [markdown]
# ### **풀이2** 파이썬다운 방식(Pythonic way)

# %% [markdown]
# 입력값이 리스트로 제공되므로 다음과 같이 reverse() 함수를 사용하면 뒤집을 수 있다.

# %%
def reverseString(self, s: List[str]) -> None:
    s.reverse()

# %% [markdown]
# ## 03 로그파일 재정렬
#
# > 로그를 재정렬하라. 기준은 다음과 같다.
#
#
#
# 1.   로그의 가장 앞 부분은 식별자다.
# 2.   문자로 구성된 로그가 숫자 로그보다 앞에 온다.
# 3.   식별자는 순서에 영향을 끼치지 않지만, 문자가 동일할 경우 식별자 순으로 한다.
# 4.   숫자 로그는 입력 순서대로 한다.
#
#
#
# > 입력: `log = ["dig1 8 1 5 1","let1 art can","dig2 3 6","let2 own kit dig","let3 art zero"]`
# > 출력: `["let1 art can","let3 art zero","let2 own kit dig","dig1 8 1 5 1","dig2 3 6"]`

# %% [markdown]
# ### **풀이1** 람다와 + 연산자를 이용

# %% [markdown]
# *  요구 조건을 얼마나 깔끔하게 처리할 수 있는지를 묻는 문제다.
# *  문자로 구성된 로그가 숫자 로그보다 이전에 오며, 숫자 로그는 입력 순서대로 둔다
# *  그렇다면 문자와 숫자를 구분하고, 숫자는 나중에 그대로 이어 붙인다.
# *  로그 자체는 숫자 로그도 모두 문자열로 지정되어 있으므로, 타입을 확인하면 모두 문자로 출력된다.
# *  따라서 다음과 같이 isdigit()을 이용해서 숫자 여부인지를 판별해 구분해본다.

# %%
def reorderLogFiles(self, logs: List[str]) -> List[str]:
    letters, digits = [], []
    for log in logs:
        if log.split()[1].isdigit():
            digits.append(log)
        else:
            letters.append(log)

    #2개의 키를 람다 표현식으로 정렬
    letters.sort(key=lambda x: (x.split()[1:], x.split()[0]))
    return letters + digits

# %% [markdown]
# ## 04 가장 흔한 단어
#
# > 금지된 단어를 제외한 가장 흔하게 등장하는 단어를 출력하라. 대소문자 구분을 하지 않으며, 구두점(마침표, 쉼표 등) 또한 무시한다.
#
# * 입력 : `paragraph = "Bob hit a ball, the hit BALL flew far after it was hit."`
# * 출력 : `"ball"`

# %% [markdown]
# ### **풀이1** 리스트 컴프리헨션, Counter 객체 사용

# %%
def mostCommonWord(self, paragraph: str, banned: List[str]) -> str:
    words = [word for word in re.sub(r'[^\w]', ' ', paragraph)
        .lower().split()
                if word not in banned]

    counts = collections.Counter(words)
    #가장 흔하게 등장하는 단어의 첫 번째 인덱스 리턴
    return counts.most_common(1)[0][0]

# %% [markdown]
# ## 05 그룹 애너그램
#
#
# > 애너그램이란: 일종의 언어유희로, 문자를 재배열하여 다른 뜻을 가진 단어로 바꾸는 것을 말한다.
#
# *   입력 : `["eat","tea","tan","ate","nat","bat"]`
# *   출력 : `[["ate","eat","tea"], ["nat","tan"],["bat"]]`

# %% [markdown]
# ### **풀이1** 정렬하여 딕셔너리에 추가

# %%
def groupAnagram(self, strs: List[str]) -> List[List[str]]:
    anagrams = collections.defaultdict(list)

    for word in strs:
        # 정렬하여 딕셔너리에 추가
        anagrams[''.join(sorted(word))].append(word)
    return anagrams.values()

# %% [markdown]
# ## 06 가장 긴 팰린드롬 부분 문자열
#
# > 가장 긴 팰린드롬 부분 문자열을 출력하라

# %% [markdown]
# 예제1
# *  입력 : `"babad"`
# *  출력 : `"bab"`
#
#
# *  설명
# "bab" 외에 "aba"도 정답이다.
#
# 예제2
# *  입력 : `"cbbd"`
# *  출력 : `"bb"`

# %% [markdown]
# ### **풀이1** 중앙을 중심으로 확장하는 풀이

# %%
def longestPalindrome(self, s: str) -> str:
    # 팰린드롬 판별 및 투 포인터 확장
    def expand(left: int, right: int) -> str:
        while left >= 0 and right <= len(s) and s[left] == s[right - 1]:
            left -= 1
            right += 1
        return s[left + 1:right - 1]

    #해당 사항이 없을 때 빠르게 리턴
    if len(s) < 2 or s == s[::-1]:
        return s
    result = ''
    # 슬라이딩 윈도우 우측으로 이동
    for i in range(len(s) - 1):
        result = max(result,
                       expand(i, i + 1),
                       expand(i, i + 2),
                       key=len)
    return result

# %% [markdown]
# ---

# %% [markdown]
# # 7장 배열

# %% [markdown]
# ## 07 두 수의 합
#
# > 덧셈하여 타겟을 만들 수 있는 배열의 두 숫자 인덱스를 리턴하자
#
# *  입력 : `num = [2, 7, 11, 15], target = 9`
# *  출력 : `[0, 1]`
# *  설명
# nums[0] + nums[1] = 2 + 7 = 9
# 따라서 0, 1을 리턴한다

# %% [markdown]
# ### **풀이1** 브루트 포스로 계산

# %%
def twoSum(self, nums: List[int], target: int) -> List[int]:
    for i in range(len(nums)):
        for j in range(i + 1, len(nums)):
            if nums[i] + nums[j] == target:
                return [i, j]

# %% [markdown]
# ### **풀이2** in을 이용한 탐색

# %%
def twoSum(self, nums: List[int], target: int) -> List[int]:
    for i, n in enumerate(nums):
        complement = target - n

        if complement in nums[i + 1:]:
            return nums.index(n), nums[i + 1:].index(complement) + (i + 1)

# %% [markdown]
# ### **풀이3** 첫 번째 수를 뺀 결과 키 조회

# %%
def twoSum(self, nums: List[int], target: int) -> List[int]:
    nums_map = {}
    #키와 값을 바꿔서 딕셔너리로 저장
    for i, num in enumerate(nums):
        nums_map[num] = i

    #타겟에서 첫 번째 수를 뺀 결과를 키로 조회
    for i, num in enumerate(nums):
        if target - num in nums_map and i != nums_map[target - num]:
            return nums.index(num), nums_map[target - num]

# %% [markdown]
# ### **풀이3** 조회 구조 개선

# %%
def twoSum(self, nums: List[int], target: int) -> List[int]:
    nums_map = {}
    # 하나의 for 문으로 통합
    for i, num in enumerate(nums):
        if target - num in nums_map:
            return [nums_map[target - num], i]
        nums_map[num] = i

# %% [markdown]
# ### **풀이5** 투 포인터 사용

# %%
def twoSum(self, nums: List[int], target: int) -> List[int]:
    left, right = 0, len(nums) - 1
    while not left == right:
        # 합이 타겟보다 크면 오른쪽 포인터를 왼쪽으로
        if nums[left] + nums[right] < target:
            right += 1
        #합이 타겟보다 작으면 왼쪽 포인터를 오른쪽으로
        elif nums[left] + num[right] > target:
            right -= 1
        else:
            return left, right

# %% [markdown]
# ## 08 빗물 트래핑
#
# > 높이를 입력받아 비 온 후 얼마나 많은 물이 쌓일 수 있는지 계산하라
# * 입력 : `[0,1,0,2,1,0,1,3,2,1,2,1]`
# * 출력 : `6`

# %% [markdown]
# ### **풀이1** 투 포인터를 최대로 이동

# %%
def trap(self, height: List[int]) -> int:
    if not height:
        return 0

    volume = 0
    left, right = 0, len(height) - 1
    left_max, right_max = height[left], height[right]

    while left < right:
        left_max, right_max = max(height[left], left_max),
                              max(height[right], right_max)
        # 더 높은 쪽을 향해 투 포인터 이동
        if left_max <= right_max:
            volume += left_max - height[left]
            left += 1
        else:
            volume += right_max - height[right]
            right -= 1
    return volume

# %% [markdown]
# ### **풀이2** 스택 쌓기

# %%
def trap(self, height: List[int]) -> int:
    stack = []
    volume = 0

    for i in range(len(height)):
        #변곡점을 만나는 경우
        while stack and height[i] > height[stack[-1]]:
            #스택에서 꺼낸다
            top = stack.pop()

            if not len(stack):
                break

            #이전과의 차이만큼 물 높이 처리
            distance = i - stack[-1] - 1
            waters = min(height[i], height[stack[-1]]) - height[top]

            volume += distance * waters

        stack.append(i)
    return volume

# %% [markdown]
# ## 09 세 수의 합
#
# > 배열을 입력받아 합으로 0을 만들 수 있는 3개의 엘리먼트를 출력하라
# * 입력 : `num = [-1, 0, 1, 2, -1, -4]`
# * 출력 : `[[-1, 0, 1], [-1, -1, 2]]`

# %% [markdown]
# ### **풀이1** 브루트 포스로 계산

# %%
def threeSum(self, nums: List[int]) -> List[List[int]]:
    results = []
    nums.sort()

    #브루트 포스 n^3 반복
    for i in range(len(nums) - 2):
        #중복된 값 건너뛰기
        if i > 0 and nums[i] == nums[i - 1]:
            continue
        for j in range(i + 1, len(nums) - 1):
            if j > i + 1 and nums[j] == nums[j - 1]:
                continue
            for k in range(j + 1, len(nums)):
                if k > j + 1 and nums[k] == nums[k - 1]:
                    continue
                if nums[i] + nums[j] + nums[k] == 0:
                    results.append((nums[i], nums[j], nums[k]))
    return results

# %% [markdown]
# ### **풀이2** 투 포인터로 합 계산

# %%
def threeSum(self, nums: List[int]) -> List[List[int]]:
    results = []
    nums.sort()

    for i in range(len(nums) - 2):
        #중복된 값 건너뛰기
        if i > 0 and nums[i] == nums[i - 1]:
            continue

        #간격을 좁혀가며 합 sum 계산
        left, right = i + 1, len(nums) - 1
        while left < right:
            sum = nums[i] + nums[left] + nums[right]
            if sum < 0:
                left += 1
            elif sum > 0:
                right -= 1
            else:
                #sum = 0인 경우이므로 정답 및 스킵 처리
                results.append((nums[i], nums[left], nums[right]))

                while left < right and nums[left] == nums[left + 1]:
                    left += 1
                while left < right and nums[right] == nums[right - 1]:
                    right -= 1
                left += 1
                right -= 1

    return results

# %% [markdown]
# ## 10 배열 파티션1
#
# > n개의 페어를 이용한 min(a, b)의 합으로 만들 수 있는 가장 큰 수를 출력하라
#
# * 입력 : `[1,4,3,2]`
# * 출력 : `4`
# * 설명 : n은 2가 되며, 최대 합은 4이다. -> `min(1,2) + min(3,4) = 4`

# %% [markdown]
# ### **풀이1** 오름차순 풀이

# %%
def arrayPairSum(self, nums: List[int]) -> int:
    sum = 0
    pair = []
    nums.sort()

    for n in nums:
        #앞에서부터 오름차순으로 페어를 만들어서 합 계산
        pair.append(n)
        if len(pair) == 2:
            sum += min(pair)
            pair = []

    return sum

# %% [markdown]
# ### **풀이2** 짝수 번째 값 계산

# %%
def arrayPairSum(self, nums: List[int]) -> int:
    sum = 0
    nums.sort()

    for i, n in enumerate(nums):
        #짝수 번째 값의 합 계산
        if i % 2 == 0:
            sum += n

    return sum

# %% [markdown]
# ### **풀이3** 파이썬다운 방식

# %%
def arrayPairSum(self, nums: List[int]) -> int:
    return sum(sorted(nums)[::2])

# %% [markdown]
# ## 11 자신을 제외한 배열의 곱
#
# > 배열을 입력받아 `output[i]`가 자신을 제외한 나머지 모든 요소의 곱셈 결과가 되도록 출력하라
#
# * 입력 : `[1,2,3,4]`
# * 출력 : `[24,12,8,6]`
# * 주의 : 나눗셈을 하지 않고 O(n)에 풀이하라

# %% [markdown]
# ### **풀이1**  왼쪽 곱셈 결과에 오른쪽 값을 차례대로 곱셈

# %%
def productExceptSelf(self, nums: List[int]) -> List[int]:
    out = []
    p = 1
    # 왼쪽 곱셈
    for i in range(0, len(nums)):
        out.append(p)
        p = p * nums[i]
    p = 1
    #왼쪽 곱셈 결과에 오른쪽 값을 차례대로 곱셈
    for i in range(len(nums) - 1, 0 - 1, -1):
        out[i] = out[i] * p
        p = p * nums[i]
    return out

# %% [markdown]
# ## 12 주식을 사고팔기 가장 좋은 시점
#
# > 한 번의 거래로 낼 수 있는 최대 이익을 산출하라
# * 입력 : `[7,1,5,3,6,4]`
# * 출력 : `5`
# * 설명 : 1일 때 사서 6일 때 팔면 5의 이익을 얻는다

# %% [markdown]
# ### **풀이1** 브루트 포스로 계산

# %%
def maxProfit(self, prices: List[int]) -> int:
    max_price = 0

    for i, price in enumerate(prices):
        for j in range(i, len(prices)):
            max_price = max(prices[j] - price, max_price)

    return max_price

# %% [markdown]
# ### **풀이2** 저점과 현재 값과의 차이 계산

# %%
def maxProfit(self, prices: List[int]) -> int:
    profit = 0
    min_price = sys.maxsize

    #최솟값과 최댓값을 계속 갱신
    for price in prices:
        min_price = min(min_price, price)
        profit = max(profit, price - min_price)

    return profit
